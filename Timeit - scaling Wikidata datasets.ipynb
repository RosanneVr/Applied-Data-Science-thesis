# %%
import requests
from requests.structures import CaseInsensitiveDict
import pandas as pd
from pandas import DataFrame
import json
import timeit
from timeit import default_timer as timer
from datetime import timedelta
import csv
import sparql
import numpy as np
import statistics

# %%
url = "https://query.wikidata.org/sparql"
iterations = 1

#Definition for retrieving data from Wikidata
def Wiki():
    loc_qry = """
        PREFIX wikibase: <http://wikiba.se/ontology#>
        PREFIX bd: <http://www.bigdata.com/rdf#>

        SELECT ?street ?streetLabel ?coords ?bagID ?city ?cityLabel ?s_class WHERE {
        VALUES ?street {wd:""" + " wd:".join([i for i in titlelist]) + """}
        OPTIONAL {?street wdt:P625 ?coords.}
        OPTIONAL {?street wdt:P5207 ?bagID . }
        OPTIONAL {?street wdt:P131 ?city . }
        # ?street wdt:P31 ?s_class .
        FILTER(?s_class = wd:Q79007 || ?s_class =  wd:Q2039348 || ?s_class = wd:Q3957)
        SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }
        }"""
    result = sparql.query(url, loc_qry)
    res = result.fetchall()
    res = [sparql.unpack_row(row) for row in res]

#Definition for retrieving a number of data points higher than 60,000
def Wiki2():
    loc_qry1 = """
    PREFIX wikibase: <http://wikiba.se/ontology#>
    PREFIX bd: <http://www.bigdata.com/rdf#>

    SELECT ?street ?streetLabel ?coords ?bagID ?city ?cityLabel ?s_class WHERE {
    VALUES ?street {wd:""" + " wd:".join([i for i in titlelist1]) + """}
    OPTIONAL {?street wdt:P625 ?coords.}
    OPTIONAL {?street wdt:P5207 ?bagID . }
    OPTIONAL {?street wdt:P131 ?city . }
    # ?street wdt:P31 ?s_class .
    FILTER(?s_class = wd:Q79007 || ?s_class =  wd:Q2039348 || ?s_class = wd:Q3957)
    SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }
    }"""
    result = sparql.query(url, loc_qry1)
    res = result.fetchall()
    res1 = [sparql.unpack_row(row) for row in res]
    loc_qry2 = """
        PREFIX wikibase: <http://wikiba.se/ontology#>
        PREFIX bd: <http://www.bigdata.com/rdf#>

        SELECT ?street ?streetLabel ?coords ?bagID ?city ?cityLabel ?s_class WHERE {
        VALUES ?street {wd:""" + " wd:".join([i for i in titlelist2]) + """}
        OPTIONAL {?street wdt:P625 ?coords.}
        OPTIONAL {?street wdt:P5207 ?bagID . }
        OPTIONAL {?street wdt:P131 ?city . }
        # ?street wdt:P31 ?s_class .
        FILTER(?s_class = wd:Q79007 || ?s_class =  wd:Q2039348 || ?s_class = wd:Q3957)
        SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }
        }"""
    result = sparql.query(url, loc_qry2)
    res = result.fetchall()
    res2 = [sparql.unpack_row(row) for row in res]
    res= res1 + res2

#Definition for retrieving a number of data points higher than 130,000
def Wiki4():
    loc_qry1 = """
        PREFIX wikibase: <http://wikiba.se/ontology#>
        PREFIX bd: <http://www.bigdata.com/rdf#>

        SELECT ?street ?streetLabel ?coords ?bagID ?city ?cityLabel ?s_class WHERE {
        VALUES ?street {wd:""" + " wd:".join([i for i in titlelist1]) + """}
        OPTIONAL {?street wdt:P625 ?coords.}
        OPTIONAL {?street wdt:P5207 ?bagID . }
        OPTIONAL {?street wdt:P131 ?city . }
        # ?street wdt:P31 ?s_class .
        FILTER(?s_class = wd:Q79007 || ?s_class =  wd:Q2039348 || ?s_class = wd:Q3957)
        SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }
        }"""
    result = sparql.query(url, loc_qry1)
    res = result.fetchall()
    res1 = [sparql.unpack_row(row) for row in res]
    loc_qry2 = """
        PREFIX wikibase: <http://wikiba.se/ontology#>
        PREFIX bd: <http://www.bigdata.com/rdf#>

        SELECT ?street ?streetLabel ?coords ?bagID ?city ?cityLabel ?s_class WHERE {
        VALUES ?street {wd:""" + " wd:".join([i for i in titlelist2]) + """}
        OPTIONAL {?street wdt:P625 ?coords.}
        OPTIONAL {?street wdt:P5207 ?bagID . }
        OPTIONAL {?street wdt:P131 ?city . }
        # ?street wdt:P31 ?s_class .
        FILTER(?s_class = wd:Q79007 || ?s_class =  wd:Q2039348 || ?s_class = wd:Q3957)
        SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }
        }"""
    result = sparql.query(url, loc_qry2)
    res = result.fetchall()
    res2 = [sparql.unpack_row(row) for row in res]
    loc_qry3 = """
        PREFIX wikibase: <http://wikiba.se/ontology#>
        PREFIX bd: <http://www.bigdata.com/rdf#>

        SELECT ?street ?streetLabel ?coords ?bagID ?city ?cityLabel ?s_class WHERE {
        VALUES ?street {wd:""" + " wd:".join([i for i in titlelist3]) + """}
        OPTIONAL {?street wdt:P625 ?coords.}
        OPTIONAL {?street wdt:P5207 ?bagID . }
        OPTIONAL {?street wdt:P131 ?city . }
        # ?street wdt:P31 ?s_class .
        FILTER(?s_class = wd:Q79007 || ?s_class =  wd:Q2039348 || ?s_class = wd:Q3957)
        SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }
        }"""
    result = sparql.query(url, loc_qry3)
    res = result.fetchall()
    res3 = [sparql.unpack_row(row) for row in res]
    loc_qry4 = """
        PREFIX wikibase: <http://wikiba.se/ontology#>
        PREFIX bd: <http://www.bigdata.com/rdf#>

        SELECT ?street ?streetLabel ?coords ?bagID ?city ?cityLabel ?s_class WHERE {
        VALUES ?street {wd:""" + " wd:".join([i for i in titlelist4]) + """}
        OPTIONAL {?street wdt:P625 ?coords.}
        OPTIONAL {?street wdt:P5207 ?bagID . }
        OPTIONAL {?street wdt:P131 ?city . }
        # ?street wdt:P31 ?s_class .
        FILTER(?s_class = wd:Q79007 || ?s_class =  wd:Q2039348 || ?s_class = wd:Q3957)
        SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }
        }"""
    result = sparql.query(url, loc_qry4)
    res = result.fetchall()
    res4 = [sparql.unpack_row(row) for row in res]
    res= res1 + res2 +res3 +res4

# %% [markdown]
# ## Timeit measurements

# %%
titlelist = []
times10000 = []

limit = 10000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

for i in range(20):
    times10000.append(timeit.Timer(Wiki).timeit(number=iterations))

# %%
titlelist = []
times20000 = [] 
limit = 20000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

for i in range(20):
    times20000.append(timeit.Timer(Wiki).timeit(number=iterations))

# %%
titlelist = []
times30000 = [] 
limit = 30000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

for i in range(20):
    times30000.append(timeit.Timer(Wiki).timeit(number=iterations))

# %%
titlelist = []
times40000 = []
limit = 40000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

for i in range(20):
    times40000.append(timeit.Timer(Wiki).timeit(number=iterations))

# %%
titlelist = []
times50000 = []
limit = 50000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

for i in range(20):
    times50000.append(timeit.Timer(Wiki).timeit(number=iterations))

# %%
titlelist = []
times60000 = []
limit = 60000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

for i in range(20):
    times60000.append(timeit.Timer(Wiki).timeit(number=iterations))

# %%
titlelist = []
time70000 = []
limit = 70000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
middle_index = length//2
titlelist1 = titlelist[:middle_index]
titlelist2 = titlelist[middle_index:]


for i in range(20):
    time70000.append(timeit.Timer(Wiki2).timeit(number=iterations))

# %%
titlelist = []
time80000 = []
limit = 80000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
middle_index = length//2
titlelist1 = titlelist[:middle_index]
titlelist2 = titlelist[middle_index:]


for i in range(20):
    time80000.append(timeit.Timer(Wiki2).timeit(number=iterations))

# %%
titlelist = []
time90000 = []
limit = 90000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
middle_index = length//2
titlelist1 = titlelist[:middle_index]
titlelist2 = titlelist[middle_index:]


for i in range(20):
    time90000.append(timeit.Timer(Wiki2).timeit(number=iterations))

# %%
titlelist = []
time100000 = []
limit = 100000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
middle_index = length//2
titlelist1 = titlelist[:middle_index]
titlelist2 = titlelist[middle_index:]


for i in range(20):
    time100000.append(timeit.Timer(Wiki2).timeit(number=iterations))

# %%
titlelist = []
time110000 = []
limit = 110000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
middle_index = length//2
titlelist1 = titlelist[:middle_index]
titlelist2 = titlelist[middle_index:]


for i in range(20):
    time110000.append(timeit.Timer(Wiki2).timeit(number=iterations))

# %%
titlelist = []
time120000 = []
limit = 120000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
middle_index = length//2
titlelist1 = titlelist[:middle_index]
titlelist2 = titlelist[middle_index:]


for i in range(20):
    time120000.append(timeit.Timer(Wiki2).timeit(number=iterations))

# %%
titlelist = []
time130000 = []
limit = 130000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
middle_index = length//2
titlelist1 = titlelist[:middle_index]
titlelist2 = titlelist[middle_index:]


for i in range(20):
    time130000.append(timeit.Timer(Wiki2).timeit(number=iterations))

# %%
titlelist = []
time140000 = []
limit = 140000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
half_index = length//2
quarter_index = length//4
half1 = titlelist[:half_index]
half2 = titlelist[half_index:]
titlelist1 = half1[:quarter_index]
titlelist2 = half1[quarter_index:]
titlelist3 = half2[:quarter_index]
titlelist4 = half2[quarter_index:]

for i in range(20):
    time140000.append(timeit.Timer(Wiki4).timeit(number=iterations))

# %%
titlelist = []
time150000 = []
limit = 150000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
half_index = length//2
quarter_index = length//4
half1 = titlelist[:half_index]
half2 = titlelist[half_index:]
titlelist1 = half1[:quarter_index]
titlelist2 = half1[quarter_index:]
titlelist3 = half2[:quarter_index]
titlelist4 = half2[quarter_index:]

for i in range(20):
    time150000.append(timeit.Timer(Wiki4).timeit(number=iterations))

# %%
titlelist = []
time160000 = []
limit = 160000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
half_index = length//2
quarter_index = length//4
half1 = titlelist[:half_index]
half2 = titlelist[half_index:]
titlelist1 = half1[:quarter_index]
titlelist2 = half1[quarter_index:]
titlelist3 = half2[:quarter_index]
titlelist4 = half2[quarter_index:]

for i in range(20):
    time160000.append(timeit.Timer(Wiki4).timeit(number=iterations))

# %%
titlelist = []
time170000 = []
limit = 170000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
half_index = length//2
quarter_index = length//4
half1 = titlelist[:half_index]
half2 = titlelist[half_index:]
titlelist1 = half1[:quarter_index]
titlelist2 = half1[quarter_index:]
titlelist3 = half2[:quarter_index]
titlelist4 = half2[quarter_index:]

for i in range(20):
    time170000.append(timeit.Timer(Wiki4).timeit(number=iterations))

# %%
titlelist = []
time180000 = []
limit = 180000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
half_index = length//2
quarter_index = length//4
half1 = titlelist[:half_index]
half2 = titlelist[half_index:]
titlelist1 = half1[:quarter_index]
titlelist2 = half1[quarter_index:]
titlelist3 = half2[:quarter_index]
titlelist4 = half2[quarter_index:]

for i in range(20):
    time180000.append(timeit.Timer(Wiki4).timeit(number=iterations))

# %%
titlelist = []
time190000 = []
limit = 190000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
half_index = length//2
quarter_index = length//4
half1 = titlelist[:half_index]
half2 = titlelist[half_index:]
titlelist1 = half1[:quarter_index]
titlelist2 = half1[quarter_index:]
titlelist3 = half2[:quarter_index]
titlelist4 = half2[quarter_index:]

for i in range(20):
    time190000.append(timeit.Timer(Wiki4).timeit(number=iterations))

# %%
titlelist = []
time200000 = []
limit = 200000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
half_index = length//2
quarter_index = length//4
half1 = titlelist[:half_index]
half2 = titlelist[half_index:]
titlelist1 = half1[:quarter_index]
titlelist2 = half1[quarter_index:]
titlelist3 = half2[:quarter_index]
titlelist4 = half2[quarter_index:]

for i in range(20):
    time200000.append(timeit.Timer(Wiki4).timeit(number=iterations))

# %%
titlelist = []
time210000 = []
limit = 210000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
half_index = length//2
quarter_index = length//4
half1 = titlelist[:half_index]
half2 = titlelist[half_index:]
titlelist1 = half1[:quarter_index]
titlelist2 = half1[quarter_index:]
titlelist3 = half2[:quarter_index]
titlelist4 = half2[quarter_index:]

for i in range(20):
    time210000.append(timeit.Timer(Wiki4).timeit(number=iterations))

# %%
titlelist = []
time220000 = []
limit = 220000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
half_index = length//2
quarter_index = length//4
half1 = titlelist[:half_index]
half2 = titlelist[half_index:]
titlelist1 = half1[:quarter_index]
titlelist2 = half1[quarter_index:]
titlelist3 = half2[:quarter_index]
titlelist4 = half2[quarter_index:]

for i in range(20):
    time220000.append(timeit.Timer(Wiki4).timeit(number=iterations))

# %%
titlelist = []
time230000 = []
limit = 230000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
half_index = length//2
quarter_index = length//4
half1 = titlelist[:half_index]
half2 = titlelist[half_index:]
titlelist1 = half1[:quarter_index]
titlelist2 = half1[quarter_index:]
titlelist3 = half2[:quarter_index]
titlelist4 = half2[quarter_index:]

for i in range(20):
    time230000.append(timeit.Timer(Wiki4).timeit(number=iterations))

# %%
titlelist = []
time240000 = []
limit = 240000

queryformat = """select ?street {{
        # ?street wdt:P31 wd:Q79007 .
        # ?street wdt:P17 wd:Q55 .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],nl". }}
        }}LIMIT {}""".format(limit)
query = str(queryformat)
result = sparql.query(url, query)
res = result.fetchall()
result = [sparql.unpack_row(row) for row in res]
test = []
for i in result:
    string = str(i)
    title = string.replace('http://www.wikidata.org/entity/', '')
    title = title.replace('[', '')
    title = title.replace(']', '')
    title = title.replace('\'', '')
    titlelist.append(title)

length = len(titlelist)
half_index = length//2
quarter_index = length//4
half1 = titlelist[:half_index]
half2 = titlelist[half_index:]
titlelist1 = half1[:quarter_index]
titlelist2 = half1[quarter_index:]
titlelist3 = half2[:quarter_index]
titlelist4 = half2[quarter_index:]

for i in range(20):
    time240000.append(timeit.Timer(Wiki4).timeit(number=iterations))

# %% [markdown]
# ## Results

# %%
print('Times:',times10000,'\nMean:', statistics.mean(times10000),'\nStandard deviation', ,statistics.stdev(times10000),'\nMax:',max(times10000),'\n')
print('Times:',times20000,'\nMean:', statistics.mean(times20000),'\nStandard deviation',statistics.stdev(times20000),'\nMax:',max(times20000),'\n')
print('Times:',times30000,'\nMean:', statistics.mean(times30000),'\nStandard deviation',statistics.stdev(times30000),'\nMax:',max(times30000),'\n')
print('Times:',times40000,'\nMean:', statistics.mean(times40000),'\nStandard deviation',statistics.stdev(times40000),'\nMax:',max(times40000),'\n')
print('Times:',times50000,'\nMean:', statistics.mean(times50000),'\nStandard deviation',statistics.stdev(times50000),'\nMax:',max(times50000),'\n')
print('Times:',times60000,'\nMean:', statistics.mean(times60000),'\nStandard deviation',statistics.stdev(times60000),'\nMax:',max(times60000),'\n')
print('Times:',times70000,'\nMean:', statistics.mean(times70000),'\nStandard deviation',statistics.stdev(times70000),'\nMax:',max(times70000),'\n')
print('Times:',times80000,'\nMean:', statistics.mean(times80000),'\nStandard deviation',statistics.stdev(times80000),'\nMax:',max(times80000),'\n')
print('Times:',times90000,'\nMean:', statistics.mean(times90000),'\nStandard deviation',statistics.stdev(times90000),'\nMax:',max(times90000),'\n')
print('Times:',times100000,'\nMean:', statistics.mean(times100000),'\nStandard deviation',statistics.stdev(times100000),'\nMax:',max(times100000),'\n')
print('Times:',times110000,'\nMean:', statistics.mean(times110000),'\nStandard deviation',statistics.stdev(times110000),'\nMax:',max(times110000),'\n')
print('Times:',times120000,'\nMean:', statistics.mean(times120000),'\nStandard deviation',statistics.stdev(times120000),'\nMax:',max(times120000),'\n')
print('Times:',times130000,'\nMean:', statistics.mean(times130000),'\nStandard deviation',statistics.stdev(times130000),'\nMax:',max(times130000),'\n')
print('Times:',times140000,'\nMean:', statistics.mean(times140000),'\nStandard deviation',statistics.stdev(times140000),'\nMax:',max(times140000),'\n')
print('Times:',times150000,'\nMean:', statistics.mean(times150000),'\nStandard deviation',statistics.stdev(times150000),'\nMax:',max(times150000),'\n')
print('Times:',times160000,'\nMean:', statistics.mean(times160000),'\nStandard deviation',statistics.stdev(times160000),'\nMax:',max(times160000),'\n')
print('Times:',times170000,'\nMean:', statistics.mean(times170000),'\nStandard deviation',statistics.stdev(times170000),'\nMax:',max(times170000),'\n')
print('Times:',times180000,'\nMean:', statistics.mean(times180000),'\nStandard deviation',statistics.stdev(times180000),'\nMax:',max(times180000),'\n')
print('Times:',times190000,'\nMean:', statistics.mean(times190000),'\nStandard deviation',statistics.stdev(times190000),'\nMax:',max(times190000),'\n')
print('Times:',times200000,'\nMean:', statistics.mean(times200000),'\nStandard deviation',statistics.stdev(times200000),'\nMax:',max(times200000),'\n')
print('Times:',times210000,'\nMean:', statistics.mean(times210000),'\nStandard deviation',statistics.stdev(times210000),'\nMax:',max(times210000),'\n')
print('Times:',times220000,'\nMean:', statistics.mean(times220000),'\nStandard deviation',statistics.stdev(times220000),'\nMax:',max(times220000),'\n')
print('Times:',times230000,'\nMean:', statistics.mean(times230000),'\nStandard deviation',statistics.stdev(times230000),'\nMax:',max(times230000),'\n')
print('Times:',times240000,'\nMean:', statistics.mean(times240000),'\nStandard deviation',statistics.stdev(times240000),'\nMax:',max(times240000),'\n')
